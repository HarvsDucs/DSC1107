# %%
import pandas as pd
import seaborn as sns

diamonds = sns.load_dataset('diamonds')

# %% [markdown]
# ## Isolating Data

# %% [markdown]
# ### Filter

# %%
import pandas as pd
import seaborn as sns

# Load the diamonds dataset
diamonds = sns.load_dataset("diamonds")

# Filter the DataFrame
filtered_diamonds = diamonds[diamonds['price'] >= 10000]

# Print the filtered DataFrame (optional)
display(filtered_diamonds)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 21927   1.51       Good     H     VS2   64.0   59.0  10000  7.25  7.19  4.62
# 21928   1.70      Ideal     J     VS2   60.5   58.0  10002  7.73  7.74  4.68
# 21929   1.03      Ideal     E    VVS2   60.6   59.0  10003  6.50  6.53  3.95
# 21930   1.23  Very Good     G    VVS2   60.6   55.0  10004  6.93  7.02  4.23
# 21931   1.25      Ideal     F     VS2   61.6   55.0  10006  6.93  6.96  4.28
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 27745   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95  8.00  5.01
# 27746   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20  8.13  5.11
# 27747   1.51      Ideal     G      IF   61.7   55.0  18806  7.37  7.41  4.56
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90  7.97  5.04
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50  8.47  5.16
#
# [5223 rows x 10 columns]

# %%
diamonds = sns.load_dataset("diamonds")

# Filter the DataFrame
filtered_diamonds = diamonds[
    (diamonds['price'] >= 10000) &
    (diamonds['clarity'].isin(['VVS1', 'IF']))
]

display(filtered_diamonds)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 21946   1.01  Very Good     F    VVS1   62.9   57.0  10019  6.35  6.41  4.01
# 21959   1.02  Very Good     E      IF   61.7   60.0  10029  6.38  6.52  3.98
# 21961   1.03  Very Good     F      IF   62.8   57.0  10032  6.40  6.47  4.04
# 21978   1.00  Very Good     F      IF   63.2   63.0  10046  6.26  6.24  3.95
# 21986   1.11      Ideal     G      IF   61.2   54.0  10053  6.71  6.73  4.11
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 27650   2.29    Premium     J      IF   61.4   60.0  18594  8.49  8.45  5.20
# 27671   1.42      Ideal     F    VVS1   60.8   56.0  18682  7.25  7.32  4.43
# 27677   1.28      Ideal     E      IF   60.7   57.0  18700  7.09  6.99  4.27
# 27733   1.51  Very Good     F    VVS1   62.6   59.0  18777  7.33  7.24  4.56
# 27747   1.51      Ideal     G      IF   61.7   55.0  18806  7.37  7.41  4.56
#
# [415 rows x 10 columns]

# %% [markdown]
# ### Select

# %%
selected_columns = diamonds[['carat', 'cut', 'color', 'clarity']]

# Print the resulting DataFrame (optional)
display(selected_columns)
# Out:
#        carat        cut color clarity
# 0       0.23      Ideal     E     SI2
# 1       0.21    Premium     E     SI1
# 2       0.23       Good     E     VS1
# 3       0.29    Premium     I     VS2
# 4       0.31       Good     J     SI2
# ...      ...        ...   ...     ...
# 53935   0.72      Ideal     D     SI1
# 53936   0.72       Good     D     SI1
# 53937   0.70  Very Good     D     SI1
# 53938   0.86    Premium     H     SI2
# 53939   0.75      Ideal     D     SI2
#
# [53940 rows x 4 columns]

# %% [markdown]
# ### Arrange

# %%
sorted_diamonds = diamonds.sort_values(by='carat', ascending=True)

# Print the sorted DataFrame (optional)
display(sorted_diamonds)
# Out:
#        carat      cut color clarity  depth  table  price      x      y     z
# 31593   0.20  Premium     E     VS2   61.1   59.0    367   3.81   3.78  2.32
# 31597   0.20    Ideal     D     VS2   61.5   57.0    367   3.81   3.77  2.33
# 31596   0.20  Premium     F     VS2   62.6   59.0    367   3.73   3.71  2.33
# 31595   0.20    Ideal     E     VS2   59.7   55.0    367   3.86   3.84  2.30
# 31594   0.20  Premium     E     VS2   59.7   62.0    367   3.84   3.80  2.28
# ...      ...      ...   ...     ...    ...    ...    ...    ...    ...   ...
# 25999   4.01  Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# 25998   4.01  Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
# 27130   4.13     Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 27630   4.50     Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27415   5.01     Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
#
# [53940 rows x 10 columns]

# %% [markdown]
# ## Deriving Information

# %% [markdown]
# ### Mutate

# %%
diamonds['price_per_carat'] = diamonds['price'] / diamonds['carat']

# Print the DataFrame with the new column (optional)
display(diamonds)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        price_per_carat
# ...

# %%
diamonds['price_per_carat'] = diamonds['price'] / diamonds['carat']

# Add a new column 'fancy_diamond' indicating if price per carat > 10000
diamonds['fancy_diamond'] = diamonds['price_per_carat'] > 10000

# Print the updated DataFrame (optional)
display(diamonds)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        price_per_carat  fancy_diamond
# ...

# %%
import numpy as np

diamonds['good_value'] = np.where(
    diamonds['carat'] > 2,
    diamonds['price'] < 5000,
    diamonds['price'] < 1000
)

display(diamonds)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# ...

# %%
diamonds['value'] = 'bad'  # Default value

diamonds.loc[
    (diamonds['carat'] > 2) & (diamonds['price'] < 5000),
    'value'
] = 'good'

diamonds.loc[
    (diamonds['carat'] > 1) & (diamonds['price'] < 2500),
    'value'
] = 'ok'

# Print the updated DataFrame (optional)
print(diamonds)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# ...

# %% [markdown]
# ### Summarize

# %%
import pandas as pd
import seaborn as sns

# Load the diamonds dataset
diamonds = sns.load_dataset("diamonds")

# Calculate 'price_per_carat' first (as in the previous step)
diamonds['price_per_carat'] = diamonds['price'] / diamonds['carat']


# Calculate the number of "fancy" diamonds
num_fancy_diamonds = (diamonds['price_per_carat'] > 10000).sum()

# Create a DataFrame for output
result_df = pd.DataFrame({'num_fancy_diamonds': [num_fancy_diamonds]})


# Print the result
print(result_df)
# Out:
#    num_fancy_diamonds
# 0                 617

# %%
diamonds['price_per_carat'] = diamonds['price'] / diamonds['carat']

# Calculate the number of "fancy" diamonds and the mean price
num_fancy_diamonds = (diamonds['price_per_carat'] > 10000).sum()
mean_diamond_price = diamonds['price'].mean()

# Create a DataFrame for the result
result_df = pd.DataFrame({
    'num_fancy_diamonds': [num_fancy_diamonds],
    'mean_diamond_price': [mean_diamond_price]
})

# Print the result
print(result_df)
# Out:
#    num_fancy_diamonds  mean_diamond_price
# 0                 617         3932.799722

# %% [markdown]
# ## Multi Step Transformations

# %% [markdown]
# ### The pipe

# %%
import pandas as pd
import seaborn as sns

# Load the diamonds dataset
diamonds = sns.load_dataset("diamonds")

# Perform the sequence of operations using chaining
processed_diamonds = (
    diamonds
    .query('cut == "Premium"')
    .assign(price_per_carat=lambda x: x['price'] / x['carat'])
    .sort_values(by='price_per_carat', ascending=False)
)

# Print the processed DataFrame (optional)
print(processed_diamonds)
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z  \
# 27530   1.07  Premium     D      IF   60.9   58.0  18279  6.67  6.57  4.03
# 26549   1.01  Premium     D      IF   61.6   56.0  16234  6.46  6.43  3.97
# 26105   1.02  Premium     D      IF   61.5   60.0  15370  6.52  6.45  3.99
# 26237   1.04  Premium     D      IF   60.6   56.0  15671  6.60  6.54  3.98
# 26003   1.02  Premium     D      IF   61.5   60.0  15231  6.45  6.52  3.99
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 28284   0.32  Premium     J     SI1   62.2   59.0    365  4.37  4.41  2.73
# 6704    0.36  Premium     J     SI1   61.6   60.0    410  4.54  4.58  2.81
# 15      0.32  Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# 31962   0.43  Premium     H      I1   62.0   59.0    452  4.78  4.83  2.98
#
#        price_per_carat
# 27530     17083.177570
# ...

# %%
processed_diamonds = (
    diamonds
    .query('cut == "Premium"')
    .assign(price_per_carat=lambda x: x['price'] / x['carat'])
)

# Create histogram of price per carat
plt.figure(figsize=(10, 6))
sns.histplot(data=processed_diamonds, x='price_per_carat')

# Add labels and title
plt.xlabel("Price Per Carat")
plt.ylabel("Frequency")
plt.title("Distribution of Price Per Carat for Premium Cut Diamonds")
plt.grid(axis='y')

plt.show()

# %% [markdown]
# ### Group By

# %%
import pandas as pd
import seaborn as sns

# Load the diamonds dataset
diamonds = sns.load_dataset("diamonds")

# Group by 'cut' and find the maximum price for each group
max_prices_by_cut = (
    diamonds
    .groupby('cut')
    ['price']
    .max()
    .reset_index(name='max_price')
)

# Print the result
print(max_prices_by_cut)
# Out:
#          cut  max_price
# 0      Ideal      18806
# 1    Premium      18823
# 2  Very Good      18818
# 3       Good      18788
# 4       Fair      18574
# C:\Users\Harvey\AppData\Local\Temp\ipykernel_7272\775508960.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby('cut')

# %%
import pandas as pd
import seaborn as sns

# Load the diamonds dataset
diamonds = sns.load_dataset("diamonds")

# Group by 'cut' and 'clarity' and find the maximum price for each group
max_prices_by_cut_clarity = (
    diamonds
    .groupby(['cut', 'clarity'])
    ['price']
    .max()
    .reset_index(name='max_price')
)

# Print the result
print(max_prices_by_cut_clarity)
# Out:
#           cut clarity  max_price
# 0       Ideal      IF      18806
# 1       Ideal    VVS1      18682
# 2       Ideal    VVS2      18768
# 3       Ideal     VS1      18780
# 4       Ideal     VS2      18779
# 5       Ideal     SI1      18787
# 6       Ideal     SI2      18804
# 7       Ideal      I1      16538
# 8     Premium      IF      18594
# 9     Premium    VVS1      17891
# 10    Premium    VVS2      18730
# 11    Premium     VS1      18795
# 12    Premium     VS2      18823
# 13    Premium     SI1      18797
# 14    Premium     SI2      18784
# 15    Premium      I1      16193
# 16  Very Good      IF      18552
# 17  Very Good    VVS1      18777
# 18  Very Good    VVS2      18211
# 19  Very Good     VS1      18500
# 20  Very Good     VS2      18691
# 21  Very Good     SI1      18818
# 22  Very Good     SI2      18692
# 23  Very Good      I1      15984
# 24       Good      IF      17499
# 25       Good    VVS1      15420
# 26       Good    VVS2      17449
# ...

# %%
import pandas as pd
import seaborn as sns

# Load the diamonds dataset
diamonds = sns.load_dataset("diamonds")

# Group, summarize, and then "ungroup" (reset index)
max_prices_by_cut_clarity = (
    diamonds
    .groupby(['cut', 'clarity'])
    ['price']
    .max()
    .reset_index(name='max_price')
)

# Print the result
print(max_prices_by_cut_clarity)
# Out:
#           cut clarity  max_price
# 0       Ideal      IF      18806
# 1       Ideal    VVS1      18682
# 2       Ideal    VVS2      18768
# 3       Ideal     VS1      18780
# 4       Ideal     VS2      18779
# 5       Ideal     SI1      18787
# 6       Ideal     SI2      18804
# 7       Ideal      I1      16538
# 8     Premium      IF      18594
# 9     Premium    VVS1      17891
# 10    Premium    VVS2      18730
# 11    Premium     VS1      18795
# 12    Premium     VS2      18823
# 13    Premium     SI1      18797
# 14    Premium     SI2      18784
# 15    Premium      I1      16193
# 16  Very Good      IF      18552
# 17  Very Good    VVS1      18777
# 18  Very Good    VVS2      18211
# 19  Very Good     VS1      18500
# 20  Very Good     VS2      18691
# 21  Very Good     SI1      18818
# 22  Very Good     SI2      18692
# 23  Very Good      I1      15984
# 24       Good      IF      17499
# 25       Good    VVS1      15420
# 26       Good    VVS2      17449
# ...

# %% [markdown]
# ### Storing Transformed Data

# %%
import pandas as pd
import seaborn as sns

# Load the diamonds dataset
diamonds = sns.load_dataset("diamonds")

# Store transformed data to variable max_prices
max_prices = (
    diamonds
    .groupby('cut')
    ['price']
    .max()
    .reset_index(name='max_price')
)

# Print the max_prices DataFrame
print(max_prices)
# Out:
#          cut  max_price
# 0      Ideal      18806
# 1    Premium      18823
# 2  Very Good      18818
# 3       Good      18788
# 4       Fair      18574
# C:\Users\Harvey\AppData\Local\Temp\ipykernel_7272\2531550885.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby('cut')
